# %%
import pandas as pd

# %%
dataframe_customers = pd.read_csv(r'./churn_customers.csv')

# %% [markdown]
# ### CUSTOMERS INFOS

# %%
# 5 PRIMEIROS CLIENTES
dataframe_customers.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No

# %%
# 5 ULTIMOS CLIENTES
dataframe_customers.tail(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents
# 7038  6840-RESVB    Male              0     Yes        Yes
# 7039  2234-XADUH  Female              0     Yes        Yes
# 7040  4801-JZAZL  Female              0     Yes        Yes
# 7041  8361-LTMKD    Male              1     Yes         No
# 7042  3186-AJIEK    Male              0      No         No

# %%
# CLIENTE SCHEMA
dataframe_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %% [markdown]
# ### CONTRACTS INFOS

# %%
dataframe_contracts = pd.read_csv(r'./churn_contracts.csv')

# %%
# 5 PRIMEIROS CONTRATOS
dataframe_contracts.head(5)
# Out:
#    customerID  tenure        Contract PaperlessBilling  \
# 0  7590-VHVEG       1  Month-to-month              Yes
# 1  5575-GNVDE      34        One year               No
# 2  3668-QPYBK       2  Month-to-month              Yes
# 3  7795-CFOCW      45        One year               No
# 4  9237-HQITU       2  Month-to-month              Yes
#
#                PaymentMethod     MonthlyCharges TotalCharges Churn
# 0           Electronic check 29.850000000000001        29.85    No
# 1               Mailed check 56.950000000000003       1889.5    No
# 2               Mailed check 53.850000000000001       108.15   Yes
# 3  Bank transfer (automatic) 42.299999999999997      1840.75    No
# 4           Electronic check 70.700000000000003       151.65   Yes

# %%
# CONTRATOS SCHEMA
dataframe_contracts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   tenure            7043 non-null   int64
#  2   Contract          7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7043 non-null   object
#  7   Churn             7043 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 440.3+ KB

# %% [markdown]
# ### SERVICES INFOS

# %%
dataframe_services = pd.read_csv(r'./churn_services.csv')

# %%
# 5 PRIMEIROS SERVIÇOS
dataframe_services.head(5)
# Out:
#    customerID PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0  7590-VHVEG           No  No phone service             DSL             No
# 1  5575-GNVDE          Yes                No             DSL            Yes
# 2  3668-QPYBK          Yes                No             DSL            Yes
# 3  7795-CFOCW           No  No phone service             DSL            Yes
# 4  9237-HQITU          Yes                No     Fiber optic             No
#
#   OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies
# 0          Yes               No          No          No              No
# 1           No              Yes          No          No              No
# 2          Yes               No          No          No              No
# 3           No              Yes         Yes          No              No
# 4           No               No          No          No              No

# %%
# SERVIÇOS SCHEMA
dataframe_services.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   PhoneService      7043 non-null   object
#  2   MultipleLines     7043 non-null   object
#  3   InternetService   7043 non-null   object
#  4   OnlineSecurity    7043 non-null   object
#  5   OnlineBackup      7043 non-null   object
#  6   DeviceProtection  7043 non-null   object
#  7   TechSupport       7043 non-null   object
#  8   StreamingTV       7043 non-null   object
#  9   StreamingMovies   7043 non-null   object
# dtypes: object(10)
# memory usage: 550.4+ KB

# %% [markdown]
# ### MUDANDO ESTRUTURA CONTRACTS (SCHEMAS)

# %%
# errors='coerce' DEIXA OS DADOS QUE NÃO FOR POSSÍVEL CONVERTER COMO NULL
dataframe_contracts['TotalCharges'] = pd.to_numeric(dataframe_contracts['TotalCharges'], errors='coerce')

dataframe_contracts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   tenure            7043 non-null   int64
#  2   Contract          7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7032 non-null   float64
#  7   Churn             7043 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 440.3+ KB

# %% [markdown]
# 11 itens ficaram ausentes (missing values)

# %% [markdown]
# ### RENOMEAR COLUNA

# %%
# MODIFICANDO APENAS UMA ÚNICA COLUNA
dataframe_customers.rename(columns={'SeniorCitizen': '+65'}, inplace=True)

dataframe_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7043 non-null   object
#  1   gender      7043 non-null   object
#  2   +65         7043 non-null   int64
#  3   Partner     7043 non-null   object
#  4   Dependents  7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
# MODIFICANDO VARIAS COLUNAS
dataframe_customers.columns = ['usuarioID', 'genero', '+65', 'casado', 'dependentes']

dataframe_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   usuarioID    7043 non-null   object
#  1   genero       7043 non-null   object
#  2   +65          7043 non-null   int64
#  3   casado       7043 non-null   object
#  4   dependentes  7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %% [markdown]
# ### MERGE (CONECTANDO VARIOS DATAFRAMES)

# %%
# FIZEMOS O MERGE E O DROP DOS IDS PARA NAO DUPLICAR A INFORMAÇÃO IGUAL
dataframe_all_infos = dataframe_customers.merge(
    dataframe_contracts, left_on=['usuarioID'], right_on=['customerID']).drop(
        columns=['customerID'], axis=1).merge(
            dataframe_services, left_on=['usuarioID'], right_on=['customerID']).drop(
                 columns=['customerID'], axis=1
            )

dataframe_all_infos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   usuarioID         7043 non-null   object
#  1   genero            7043 non-null   object
#  2   +65               7043 non-null   int64
#  3   casado            7043 non-null   object
#  4   dependentes       7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   Contract          7043 non-null   object
#  7   PaperlessBilling  7043 non-null   object
#  8   PaymentMethod     7043 non-null   object
#  9   MonthlyCharges    7043 non-null   float64
#  10  TotalCharges      7032 non-null   float64
#  11  Churn             7043 non-null   object
#  12  PhoneService      7043 non-null   object
#  13  MultipleLines     7043 non-null   object
#  14  InternetService   7043 non-null   object
#  15  OnlineSecurity    7043 non-null   object
#  16  OnlineBackup      7043 non-null   object
#  17  DeviceProtection  7043 non-null   object
#  18  TechSupport       7043 non-null   object
#  19  StreamingTV       7043 non-null   object
#  20  StreamingMovies   7043 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.1+ MB

# %% [markdown]
# ### LIDANDO COM DADOS AUSENTES

# %%
# DE TODAS AS COLUNAS, QUERO A SOMA DE QUANTOS DADOS SAO NA
dataframe_all_infos.isna().sum()
# Out:
# usuarioID            0
# genero               0
# +65                  0
# casado               0
# dependentes          0
# tenure               0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# dtype: int64

# %%
# QUAIS DADOS DO DATAFRAME ESTÃO AUSENTES
# OBS: QUANDO ELE FALA DE LINHAS, ELE QUER DIZER X -> HORIZONTAL 0 / Y -> VERTICAL 1
dataframe_all_infos[dataframe_all_infos.isna().any(axis=1)]
# Out:
#        usuarioID  genero  +65 casado dependentes  tenure  Contract  \
# 488   4472-LVYGI  Female    0    Yes         Yes       0  Two year
# 753   3115-CZMZD    Male    0     No         Yes       0  Two year
# 936   5709-LVOEQ  Female    0    Yes         Yes       0  Two year
# 1082  4367-NUYAO    Male    0    Yes         Yes       0  Two year
# 1340  1371-DWPAZ  Female    0    Yes         Yes       0  Two year
# 3331  7644-OMVMY    Male    0    Yes         Yes       0  Two year
# 3826  3213-VVOLG    Male    0    Yes         Yes       0  Two year
# 4380  2520-SGTTA  Female    0    Yes         Yes       0  Two year
# 5218  2923-ARZLG    Male    0    Yes         Yes       0  One year
# 6670  4075-WKNIU  Female    0    Yes         Yes       0  Two year
# 6754  2775-SEFEE    Male    0     No         Yes       0  Two year
#
#      PaperlessBilling              PaymentMethod     MonthlyCharges  ...  \
# 488               Yes  Bank transfer (automatic) 52.549999999999997  ...
# 753                No               Mailed check 20.250000000000000  ...
# 936                No               Mailed check 80.849999999999994  ...
# 1082               No               Mailed check 25.750000000000000  ...
# 1340               No    Credit card (automatic) 56.049999999999997  ...
# 3331               No               Mailed check 19.850000000000001  ...
# 3826               No               Mailed check 25.350000000000001  ...
# 4380               No               Mailed check 20.000000000000000  ...
# 5218              Yes               Mailed check 19.699999999999999  ...
# 6670               No               Mailed check 73.349999999999994  ...
# 6754              Yes  Bank transfer (automatic) 61.899999999999999  ...
#
#       Churn PhoneService     MultipleLines InternetService  \
# 488      No           No  No phone service             DSL
# 753      No          Yes                No              No
# 936      No          Yes                No             DSL
# 1082     No          Yes               Yes              No
# 1340     No           No  No phone service             DSL
# 3331     No          Yes                No              No
# 3826     No          Yes               Yes              No
# 4380     No          Yes                No              No
# 5218     No          Yes                No              No
# 6670     No          Yes               Yes             DSL
# 6754     No          Yes               Yes             DSL
#
#            OnlineSecurity         OnlineBackup     DeviceProtection  \
# 488                   Yes                   No                  Yes
# 753   No internet service  No internet service  No internet service
# 936                   Yes                  Yes                  Yes
# 1082  No internet service  No internet service  No internet service
# 1340                  Yes                  Yes                  Yes
# 3331  No internet service  No internet service  No internet service
# 3826  No internet service  No internet service  No internet service
# 4380  No internet service  No internet service  No internet service
# 5218  No internet service  No internet service  No internet service
# 6670                   No                  Yes                  Yes
# 6754                  Yes                  Yes                   No
#
#               TechSupport          StreamingTV      StreamingMovies
# 488                   Yes                  Yes                   No
# 753   No internet service  No internet service  No internet service
# 936                    No                  Yes                  Yes
# 1082  No internet service  No internet service  No internet service
# 1340                  Yes                  Yes                   No
# 3331  No internet service  No internet service  No internet service
# 3826  No internet service  No internet service  No internet service
# 4380  No internet service  No internet service  No internet service
# 5218  No internet service  No internet service  No internet service
# 6670                  Yes                  Yes                   No
# 6754                  Yes                   No                   No
#
# [11 rows x 21 columns]

# %%
# QUANTAS COLUNAS DO DATAFRAME TEM PELO MENOS 1 DADO NAN
dataframe_all_infos.isna().any(axis=0).sum()
# Out:
# np.int64(1)

# %% [markdown]
# ### MANIPULAR VALORES AUSENTES

# %%
# TROCANDO OS VALORES NULOS DA COLUNA TOTALCHARGES PARA 0
dataframe_all_infos.fillna(value={ 'TotalCahrges': 0 })
# Out:
#        usuarioID  genero  +65 casado dependentes  tenure        Contract  \
# 0     7590-VHVEG  Female    0    Yes          No       1  Month-to-month
# 1     5575-GNVDE    Male    0     No          No      34        One year
# 2     3668-QPYBK    Male    0     No          No       2  Month-to-month
# 3     7795-CFOCW    Male    0     No          No      45        One year
# 4     9237-HQITU  Female    0     No          No       2  Month-to-month
# ...          ...     ...  ...    ...         ...     ...             ...
# 7038  6840-RESVB    Male    0    Yes         Yes      24        One year
# 7039  2234-XADUH  Female    0    Yes         Yes      72        One year
# 7040  4801-JZAZL  Female    0    Yes         Yes      11  Month-to-month
# 7041  8361-LTMKD    Male    1    Yes          No       4  Month-to-month
# 7042  3186-AJIEK    Male    0     No          No      66        Two year
#
#      PaperlessBilling              PaymentMethod      MonthlyCharges  ...  \
# 0                 Yes           Electronic check  29.850000000000001  ...
# 1                  No               Mailed check  56.950000000000003  ...
# 2                 Yes               Mailed check  53.850000000000001  ...
# 3                  No  Bank transfer (automatic)  42.299999999999997  ...
# 4                 Yes           Electronic check  70.700000000000003  ...
# ...               ...                        ...                 ...  ...
# 7038              Yes               Mailed check  84.799999999999997  ...
# 7039              Yes    Credit card (automatic) 103.200000000000003  ...
# 7040              Yes           Electronic check  29.600000000000001  ...
# 7041              Yes               Mailed check  74.400000000000006  ...
# 7042              Yes  Bank transfer (automatic) 105.650000000000006  ...
#
#       Churn PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0        No           No  No phone service             DSL             No
# 1        No          Yes                No             DSL            Yes
# 2       Yes          Yes                No             DSL            Yes
# 3        No           No  No phone service             DSL            Yes
# 4       Yes          Yes                No     Fiber optic             No
# ...     ...          ...               ...             ...            ...
# 7038     No          Yes               Yes             DSL            Yes
# 7039     No          Yes               Yes     Fiber optic             No
# 7040     No           No  No phone service             DSL            Yes
# 7041    Yes          Yes               Yes     Fiber optic             No
# 7042     No          Yes                No     Fiber optic            Yes
#
#      OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies
# 0             Yes               No          No          No              No
# 1              No              Yes          No          No              No
# 2             Yes               No          No          No              No
# 3              No              Yes         Yes          No              No
# 4              No               No          No          No              No
# ...           ...              ...         ...         ...             ...
# 7038           No              Yes         Yes         Yes             Yes
# 7039          Yes              Yes          No         Yes             Yes
# 7040           No               No          No          No              No
# 7041           No               No          No          No              No
# 7042           No              Yes         Yes         Yes             Yes
#
# [7043 rows x 21 columns]

# %%
# DROPANDO COLUNAS QUE CONTEM VALORES NULOS
dataframe_all_infos.dropna(axis=1)
# Out:
#        usuarioID  genero  +65 casado dependentes  tenure        Contract  \
# 0     7590-VHVEG  Female    0    Yes          No       1  Month-to-month
# 1     5575-GNVDE    Male    0     No          No      34        One year
# 2     3668-QPYBK    Male    0     No          No       2  Month-to-month
# 3     7795-CFOCW    Male    0     No          No      45        One year
# 4     9237-HQITU  Female    0     No          No       2  Month-to-month
# ...          ...     ...  ...    ...         ...     ...             ...
# 7038  6840-RESVB    Male    0    Yes         Yes      24        One year
# 7039  2234-XADUH  Female    0    Yes         Yes      72        One year
# 7040  4801-JZAZL  Female    0    Yes         Yes      11  Month-to-month
# 7041  8361-LTMKD    Male    1    Yes          No       4  Month-to-month
# 7042  3186-AJIEK    Male    0     No          No      66        Two year
#
#      PaperlessBilling              PaymentMethod      MonthlyCharges Churn  \
# 0                 Yes           Electronic check  29.850000000000001    No
# 1                  No               Mailed check  56.950000000000003    No
# 2                 Yes               Mailed check  53.850000000000001   Yes
# 3                  No  Bank transfer (automatic)  42.299999999999997    No
# 4                 Yes           Electronic check  70.700000000000003   Yes
# ...               ...                        ...                 ...   ...
# 7038              Yes               Mailed check  84.799999999999997    No
# 7039              Yes    Credit card (automatic) 103.200000000000003    No
# 7040              Yes           Electronic check  29.600000000000001    No
# 7041              Yes               Mailed check  74.400000000000006   Yes
# 7042              Yes  Bank transfer (automatic) 105.650000000000006    No
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# 1             Yes                No             DSL            Yes
# 2             Yes                No             DSL            Yes
# 3              No  No phone service             DSL            Yes
# 4             Yes                No     Fiber optic             No
# ...           ...               ...             ...            ...
# 7038          Yes               Yes             DSL            Yes
# 7039          Yes               Yes     Fiber optic             No
# 7040           No  No phone service             DSL            Yes
# 7041          Yes               Yes     Fiber optic             No
# 7042          Yes                No     Fiber optic            Yes
#
#      OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies
# 0             Yes               No          No          No              No
# 1              No              Yes          No          No              No
# 2             Yes               No          No          No              No
# 3              No              Yes         Yes          No              No
# 4              No               No          No          No              No
# ...           ...              ...         ...         ...             ...
# 7038           No              Yes         Yes         Yes             Yes
# 7039          Yes              Yes          No         Yes             Yes
# 7040           No               No          No          No              No
# 7041           No               No          No          No              No
# 7042           No              Yes         Yes         Yes             Yes
#
# [7043 rows x 20 columns]

# %% [markdown]
# NUMERO DE COLUNAS ABAIXOU DE 21 PARA 20

# %%
# DROPANDO LINHAS QUE CONTEM VALORES NULOS
dataframe_all_infos.dropna(axis=0)
# Out:
#        usuarioID  genero  +65 casado dependentes  tenure        Contract  \
# 0     7590-VHVEG  Female    0    Yes          No       1  Month-to-month
# 1     5575-GNVDE    Male    0     No          No      34        One year
# 2     3668-QPYBK    Male    0     No          No       2  Month-to-month
# 3     7795-CFOCW    Male    0     No          No      45        One year
# 4     9237-HQITU  Female    0     No          No       2  Month-to-month
# ...          ...     ...  ...    ...         ...     ...             ...
# 7038  6840-RESVB    Male    0    Yes         Yes      24        One year
# 7039  2234-XADUH  Female    0    Yes         Yes      72        One year
# 7040  4801-JZAZL  Female    0    Yes         Yes      11  Month-to-month
# 7041  8361-LTMKD    Male    1    Yes          No       4  Month-to-month
# 7042  3186-AJIEK    Male    0     No          No      66        Two year
#
#      PaperlessBilling              PaymentMethod      MonthlyCharges  ...  \
# 0                 Yes           Electronic check  29.850000000000001  ...
# 1                  No               Mailed check  56.950000000000003  ...
# 2                 Yes               Mailed check  53.850000000000001  ...
# 3                  No  Bank transfer (automatic)  42.299999999999997  ...
# 4                 Yes           Electronic check  70.700000000000003  ...
# ...               ...                        ...                 ...  ...
# 7038              Yes               Mailed check  84.799999999999997  ...
# 7039              Yes    Credit card (automatic) 103.200000000000003  ...
# 7040              Yes           Electronic check  29.600000000000001  ...
# 7041              Yes               Mailed check  74.400000000000006  ...
# 7042              Yes  Bank transfer (automatic) 105.650000000000006  ...
#
#       Churn PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0        No           No  No phone service             DSL             No
# 1        No          Yes                No             DSL            Yes
# 2       Yes          Yes                No             DSL            Yes
# 3        No           No  No phone service             DSL            Yes
# 4       Yes          Yes                No     Fiber optic             No
# ...     ...          ...               ...             ...            ...
# 7038     No          Yes               Yes             DSL            Yes
# 7039     No          Yes               Yes     Fiber optic             No
# 7040     No           No  No phone service             DSL            Yes
# 7041    Yes          Yes               Yes     Fiber optic             No
# 7042     No          Yes                No     Fiber optic            Yes
#
#      OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies
# 0             Yes               No          No          No              No
# 1              No              Yes          No          No              No
# 2             Yes               No          No          No              No
# 3              No              Yes         Yes          No              No
# 4              No               No          No          No              No
# ...           ...              ...         ...         ...             ...
# 7038           No              Yes         Yes         Yes             Yes
# 7039          Yes              Yes          No         Yes             Yes
# 7040           No               No          No          No              No
# 7041           No               No          No          No              No
# 7042           No              Yes         Yes         Yes             Yes
#
# [7032 rows x 21 columns]

# %% [markdown]
# NUMERO DE LINHAS ABAIXOU DE 7043 PARA 7032

# %% [markdown]
# # ANALÍSE UNIVARIADA
# ENCONTRAR EM BASE DE DADOS, QUAIS CLIENTES SÃO MAIS PROPENSOS AO CHURN
#
# SUPOSIÇÕES
# - FAIXA ETÁRIA TEM FORTE RELAÇÃO
# - TIPO DE CONTRATO, MES, SEMESTRAL OU ANUAL
# - CLIENTE COM MENOS DE 6 MESES DE CONTRATO

# %%
# ENCONTRAR QUAIS TIPOS DE VALORES UNICOS EXISTEM EM UMA COLUNA
dataframe_all_infos['Churn'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %% [markdown]
# NO CASO AQUI, YES OU NO SÃO OS DADOS UNICOS

# %%
# VISÃO DE FATIA DE CLIENTES ESTÃO AO CHURN NA COLUNA
dataframe_all_infos['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
# VISÃO DE FATIA DE CLIENTES ESTÃO AO CHURN NA COLUNA (EM PORCENTAGEM)
dataframe_all_infos['Churn'].value_counts(normalize=True)
# Out:
# Churn
# No    0.734630129206304
# Yes   0.265369870793696
# Name: proportion, dtype: float64

# %%
# VISÃO DE FATIA DE CLIENTES ESTÃO AO CHURN NA COLUNA (EM BARRAS PORCENTAGEM)
xy = dataframe_all_infos['Churn'].value_counts(normalize=True).plot.bar()

# FAZ COM QUE APARECA OS DADOS EXATO ACIMA DAS BARRAS
xy.bar_label(xy.containers[0])
# Out:
# [Text(0, 0, '0.73463'), Text(0, 0, '0.26537')]

# %%
# ENCONTRAR QUAIS TIPOS DE VALORES UNICOS EXISTEM EM UMA COLUNA
dataframe_all_infos['Contract'].unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
# VISÃO DE FATIA DE CONTRATOS QUE ESTÃO NA COLUNA (EM BARRAS)
xy = dataframe_all_infos['Contract'].value_counts().plot.bar()

# FAZ COM QUE APARECA OS DADOS EXATO ACIMA DAS BARRAS
xy.bar_label(xy.containers[0])
# Out:
# [Text(0, 0, '3875'), Text(0, 0, '1695'), Text(0, 0, '1473')]

# %%
# AGRUPAMENTO APRESENTANDO QUANTIDADE DE CLIENTES POR TEMPO DE CONTRATO
dataframe_all_infos.groupby(['tenure'])['tenure'].count().sort_values(ascending=False)
# Out:
# tenure
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: tenure, Length: 73, dtype: int64

# %%
# AGRUPAMENTO APRESENTANDO QUANTIDADE DE CLIENTES POR TEMPO DE CONTRATO EM BARRAS
dataframe_all_infos.groupby(['tenure'])['tenure'].count().sort_values().plot.barh(figsize= (20, 20))
# Out:
# <Axes: ylabel='tenure'>

# %% [markdown]
# ### ANALÍSE BIVARIADA

# %%
# CLIENTES COM CONTRATOS MENSAIS SÃO MAIS PROPENSOS AO CHURN
# TABELA DE CONTINGÊNCIA ENTRE CONTRATO E CHURN
pd.crosstab(dataframe_all_infos['Churn'], dataframe_all_infos['Contract'], normalize='index', margins=True, margins_name='Total')
# NORMALIZE INDEX, INDICA PORCENTAGEM EM RELAÇÃO A PROPORÇÃO, EXEMPLO EM YES AS PORCENTAGENS SÃO SOMENTE EM RELAÇÃO AO YES
# Out:
# Contract    Month-to-month          One year          Two year
# Churn
# No       0.429068419018168 0.252609199845381 0.318322381136452
# Yes      0.885500267522739 0.088817549491707 0.025682182985554
# Total    0.550191679681954 0.209143830753940 0.240664489564106

# %%
# COMO APRESENTAR NÚMEROS DECIMAIS SEM A NOTAÇÃO CIENTÍFICA
pd.set_option('display.float_format', lambda x: '%.15f' % x)

# %%
# CRIANDO UMA NOVA COLUNA 
import numpy as np

dataframe_all_infos['TempoMenor6Meses'] = np.where(dataframe_all_infos['tenure'] < 6, 'Yes', 'No')
dataframe_all_infos.head() # CRIOU NO FIM DO DATAFRAME
# Out:
#     usuarioID  genero  +65 casado dependentes  tenure        Contract  \
# 0  7590-VHVEG  Female    0    Yes          No       1  Month-to-month
# 1  5575-GNVDE    Male    0     No          No      34        One year
# 2  3668-QPYBK    Male    0     No          No       2  Month-to-month
# 3  7795-CFOCW    Male    0     No          No      45        One year
# 4  9237-HQITU  Female    0     No          No       2  Month-to-month
#
#   PaperlessBilling              PaymentMethod     MonthlyCharges  ...  \
# 0              Yes           Electronic check 29.850000000000001  ...
# 1               No               Mailed check 56.950000000000003  ...
# 2              Yes               Mailed check 53.850000000000001  ...
# 3               No  Bank transfer (automatic) 42.299999999999997  ...
# 4              Yes           Electronic check 70.700000000000003  ...
#
#    PhoneService     MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0            No  No phone service             DSL             No          Yes
# 1           Yes                No             DSL            Yes           No
# 2           Yes                No             DSL            Yes          Yes
# 3            No  No phone service             DSL            Yes           No
# 4           Yes                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies TempoMenor6Meses
# 0               No          No          No              No              Yes
# 1              Yes          No          No              No               No
# 2               No          No          No              No              Yes
# 3              Yes         Yes          No              No               No
# 4               No          No          No              No              Yes
#
# [5 rows x 22 columns]

# %%
# CALCULANDO SCORE E P_VALUES
from scipy.stats import chi2_contingency

# ANTES DEVEMOS FAZER O CRIZAMENTO DE CATEGORIAS (CONTINGÊNCIA)
data_contigency = pd.crosstab(dataframe_all_infos['Churn'], dataframe_all_infos['TempoMenor6Meses'])

# SCORES
chi_data_contigency = chi2_contingency(data_contigency)

chi_data_contigency_score = pd.Series(chi_data_contigency[0])
chi_data_contigency_pvalues = pd.Series(chi_data_contigency[1])


# DATAFRAME DOS SCORES
scores_dataframe = pd.DataFrame({'Score': chi_data_contigency_score, 'p_values': chi_data_contigency_pvalues})
scores_dataframe
# Out:
#                 Score          p_values
# 0 669.721615828710242 0.000000000000000

# %% [markdown]
# TENDO EM VISTA ESSES RESULTADOS, VALE DIZER QUE, AS VARIAVEIS ESTÃO RELACIONADAS JA QUE O P_VALUES É MENOR DO QUE 0.05, E A RELAÇÃO MEDIDA É CONSIDERADA ALTA EM RELAÇÃO AO SCORE

# %%
# PLOT SCATTER ENTRE TENURE E TOTALCHARGES
dataframe_all_infos.plot.scatter(x='tenure', y='TotalCharges')
# Out:
# <Axes: xlabel='tenure', ylabel='TotalCharges'>

# %% [markdown]
# ### DETECÇÃO DE OUTLIERS

# %%
# PLOT BOX DE TOTAL CHARGES
dataframe_all_infos['TotalCharges'].plot.box()
# Out:
# <Axes: >

# %% [markdown]
# SÓ PARA DEIXAR EXPLICADO, O 1(PRIMEIRO) QUANTIL 0.25% É A LINHA AZUL QUE ESTÁ ABAIXO DA LINHA VERDE (ONDE FECHA A BOX)
# O 2(SEGUNDO) QUANTIL 0.5% É A MEDIANA(LINAH VERDE) DA BOX, E O 3(TERCEIRO) QUANTIL 0.75% É A LINHA AZUL ACIMA DA LINHA VERDE (FECHA A BOX ACIMA)

# %%
# BOX PLOT COM APENAS O TOTAL CHARGES DE MONTH-TO-MONTH
df_month = dataframe_all_infos[dataframe_all_infos['Contract'] == 'Month-to-month']['TotalCharges']
df_month.plot.box()
# Out:
# <Axes: >

# %%
# VERIFICANDO SE OS DADOS SEGUEM UMA DISTRIBUIÇÃO NORMAL(FORMATO DE SINO)
df_month.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# NO CASO AQUI, É UMA DISTRIBUIÇÃO POSITIVA, POR CONTA DA CAUDA SER PARA O LADO DIREITO

# %%
# IQR USAMOS QUANDO A DISTRIBUIÇÃO NÃO É NORMAL(FORMATO DE SINO)
# IQR É O CALCULO DO RANGE INTERQUARTIL - AS BORDAS DOS QUARTIS
# FORMULA -> IQR = 3o QUARTIL - 1o QUARTIL

q1_totalcharges = df_month.quantile(0.25)
q3_totalcharges = df_month.quantile(0.75)

iqr_totalcharges = q3_totalcharges - q1_totalcharges
iqr_totalcharges
# Out:
# np.float64(1906.4)

# %% [markdown]
# O RANGE DOS QUARTIS SÃO U$ 1906.4
#
# OU SEJA, TODOS OS VALORES QUE ESTIVEREM ACIMA OU ABAIXO DO RANGE DE 1.5 SÃO CONSIDERADOS OUTLIERS

# %%
# LIMITES INFERIOR E SUPERIOR COM LIMITE DE RANGE 1.5
limite_inf_totalcharges = q1_totalcharges - (iqr_totalcharges * 1.5)
limite_sup_totalcharges = q3_totalcharges + (iqr_totalcharges * 1.5)
limite_inf_totalcharges, limite_sup_totalcharges
# Out:
# (np.float64(-2699.5000000000005), np.float64(4926.1))

# %%
# MOSTRAR QUANTOS OUTLIERS EXISTEM
df_month[(df_month < limite_inf_totalcharges) | (df_month > limite_sup_totalcharges)].count()
# Out:
# np.int64(200)

# %%
df_month.shape
# Out:
# (3875,)
